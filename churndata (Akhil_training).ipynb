# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sb
import seaborn as sns

# %%
A=pd.read_csv("ChurnData.csv")

# %%
A.head()
# Out:
#         msisdn state  accountLength  areaCode internationalPlan voiceMailPlan  \
# 0  22241029622    KS            128       415                no           yes
# 1  22241029627    OH            107       415                no           yes
# 2  22241029639    NJ            137       415                no            no
# 3  22241029641    OH             84       408               yes            no
# 4  22241029646    OK             75       415               yes            no
#
#    numberVmailMessages  totalDayMinutes  totalDayCalls  totalDayCharge  ...  \
# 0                   25            265.1            110           45.07  ...
# 1                   26            161.6            123           27.47  ...
# 2                    0            243.4            114           41.38  ...
# 3                    0            299.4             71           50.90  ...
# 4                    0            166.7            113           28.34  ...
#
# ...

# %%
A.shape
# Out:
# (2890, 21)

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890 entries, 0 to 2889
# Data columns (total 21 columns):
# msisdn                        2890 non-null int64
# state                         2890 non-null object
# accountLength                 2890 non-null int64
# areaCode                      2890 non-null int64
# internationalPlan             2890 non-null object
# voiceMailPlan                 2890 non-null object
# numberVmailMessages           2890 non-null int64
# totalDayMinutes               2890 non-null float64
# totalDayCalls                 2890 non-null int64
# totalDayCharge                2890 non-null float64
# totalEveMinutes               2890 non-null float64
# totalEveCalls                 2890 non-null int64
# totalEveCharge                2890 non-null float64
# totalNightMinutes             2890 non-null float64
# totalNightCalls               2890 non-null int64
# totalNightCharge              2890 non-null float64
# ...

# %%
A.describe()
# Out:
#              msisdn  accountLength     areaCode  numberVmailMessages  \
# count  2.890000e+03    2890.000000  2890.000000          2890.000000
# mean   2.224103e+10     100.798962   437.611765             8.125952
# std    5.660506e+03      39.823608    42.609663            13.707448
# min    2.224101e+10       1.000000   408.000000             0.000000
# 25%    2.224102e+10      74.000000   415.000000             0.000000
# 50%    2.224103e+10     100.000000   415.000000             0.000000
# 75%    2.224103e+10     127.000000   510.000000            20.000000
# max    2.224104e+10     243.000000   510.000000            51.000000
#
#        totalDayMinutes  totalDayCalls  totalDayCharge  totalEveMinutes  \
# count      2890.000000    2890.000000     2890.000000      2890.000000
# mean        180.029516     100.504498       30.605557       201.128028
# std          54.638621      20.138276        9.288526        50.953424
# ...

# %%
A.corr()
# Out:
#                               msisdn  accountLength  areaCode  \
# msisdn                      1.000000      -0.052804  0.015415
# accountLength              -0.052804       1.000000 -0.032051
# areaCode                    0.015415      -0.032051  1.000000
# numberVmailMessages         0.000776      -0.003685 -0.000875
# totalDayMinutes            -0.000844       0.004773 -0.007994
# totalDayCalls              -0.032691       0.044025 -0.004229
# totalDayCharge             -0.000845       0.004770 -0.007996
# totalEveMinutes            -0.007712      -0.009927 -0.002056
# totalEveCalls              -0.003987       0.025032 -0.007342
# totalEveCharge             -0.007701      -0.009916 -0.002036
# totalNightMinutes          -0.027894      -0.006749 -0.002232
# totalNightCalls             0.004624      -0.005917  0.010654
# totalNightCharge           -0.027865      -0.006756 -0.002258
# totalIntlMinutes           -0.030676       0.021009 -0.015104
# ...

# %%
CAT=[]
CON=[]
for i in A.columns:
    if (A[i].dtypes=="object"):
        CAT.append(i)
    else:
        CON.append(i)

# %%
CAT
# Out:
# ['state', 'internationalPlan', 'voiceMailPlan']

# %%
CON
# Out:
# ['msisdn',
#  'accountLength',
#  'areaCode',
#  'numberVmailMessages',
#  'totalDayMinutes',
#  'totalDayCalls',
#  'totalDayCharge',
#  'totalEveMinutes',
#  'totalEveCalls',
#  'totalEveCharge',
#  'totalNightMinutes',
#  'totalNightCalls',
#  'totalNightCharge',
#  'totalIntlMinutes',
#  'totalIntlCalls',
#  'totalIntlCharge',
#  'numberCustomerServiceCalls',
#  'churner']

# %%
#import seaborn as sb 
#sb.pairplot(A)

# %%
sb.distplot(A.accountLength)

# %%
sb.countplot(A.churner)

# %% [markdown]
# # Categorical scatterplots

# %% [markdown]
# # Strip plot

# %%
sns.catplot(x="churner", y="accountLength", kind='strip',data=A[:250]);

# %% [markdown]
# # Swarm plot

# %%
sns.catplot(x="churner", y="accountLength", kind='swarm',data=A[:250]);

# %%
sns.catplot(x="churner", y="accountLength", kind='swarm',data=A);

# %% [markdown]
# # Box plot

# %%
sns.catplot(x="churner", y="accountLength",kind="box",data=A);
#(x="churner", y="accountLength", kind='swarm',data=A)

# %% [markdown]
# # Violin plot

# %%
sns.catplot(x="churner", y="accountLength", kind='violin',data=A)

# %% [markdown]
# # Boxen plot

# %%
sns.catplot(x="churner", y="accountLength", kind='boxen',data=A)

# %% [markdown]
# # Point plot

# %%
sns.catplot(x="churner", y="accountLength", kind='point',data=A)

# %% [markdown]
# # Bar plots

# %%
sns.catplot(x="churner", y="accountLength", kind='bar',data=A)

# %% [markdown]
# # Density plots

# %%
# distribution of Item Visibility
plt.figure(figsize=(10,10))
sns.kdeplot(data_A['Item_Visibility'], shade=True);

# %%
import matplotlib.pyplot as plt
for i in CON:
    plt.scatter(A[i],A.accountLength,c="red")
    plt.ylabel("accountLength")
    plt.xlabel(i)
    plt.title("accountLength vs %s"%i)
    plt.show()

# %%
for i in CAT:
    print(i)
    sb.boxplot(A[i],A.accountLength)
    plt.show()
# Out:
# state
# internationalPlan
# voiceMailPlan

# %% [markdown]
# # Discover outliers with mathematical function (Z-Score)

# %%
from scipy import stats
import numpy as np

# %%
z = np.abs(stats.zscore(A[['msisdn','accountLength','areaCode','numberVmailMessages','totalDayMinutes','totalDayCalls',
                           'totalDayCharge','totalEveMinutes','totalEveCalls','totalEveCharge','totalNightMinutes',
                           'totalNightCalls','totalNightCharge','totalIntlMinutes','totalIntlCalls','totalIntlCharge',
                           'numberCustomerServiceCalls']]))
print(z)
# Out:
# [[0.56289738 0.68315621 0.53076406 ... 0.60784532 0.09013008 0.42159207]
#  [0.56378084 0.15573956 0.53076406 ... 0.60784532 1.24866483 0.42159207]
#  [0.56590116 0.90919192 0.53076406 ... 0.21245493 0.69975891 1.19224424]
#  ...
#  [2.19351705 0.83384669 0.53076406 ... 0.1976952  0.31150839 0.3490601 ]
#  [2.19263359 1.18545779 0.53076406 ... 1.01799545 0.2311807  0.42159207]
#  [2.19139673 0.19587154 0.53076406 ... 0.62260505 0.66581189 0.42159207]]

# %%
#Looking the code and the output above, it is difficult to say which data point is an outlier.
#Let’s try and define a threshold to identify an outlier.

threshold = 3
print(np.where(z > 3))
# Out:
# (array([  22,   32,   32,   41,   58,  115,  115,  179,  179,  182,  185,
#         219,  244,  244,  272,  301,  314,  314,  329,  332,  343,  343,
#         365,  365,  377,  416,  468,  474,  483,  488,  488,  493,  504,
#         514,  522,  533,  533,  542,  595,  595,  636,  642,  646,  674,
#         692,  694,  712,  712,  721,  740,  756,  762,  762,  778,  817,
#         821,  821,  837,  845,  854,  863,  878,  878,  883,  883,  883,
#         889,  889,  902,  908,  921,  922,  922,  957,  960,  974,  982,
#         985,  985, 1021, 1028, 1028, 1052, 1052, 1080, 1080, 1092, 1113,
#        1113, 1121, 1142, 1144, 1179, 1233, 1233, 1260, 1260, 1273, 1317,
#        1317, 1325, 1333, 1345, 1345, 1345, 1355, 1392, 1397, 1397, 1397,
#        1400, 1400, 1407, 1408, 1419, 1445, 1445, 1502, 1551, 1564, 1564,
#        1567, 1615, 1638, 1694, 1751, 1831, 1865, 1886, 1889, 1912, 1919,
#        1986, 1986, 1989, 2001, 2212, 2223, 2269, 2288, 2321, 2321, 2327,
# ...

# %%
#Don’t be confused by the results. The first array contains the list of row numbers and second array respective column numbers,
#which mean z[22][14] have a Z-score higher than 3 and so on ....

print(z[22][14])
print(z[32][7])
print(z[32][9])
# Out:
# 5.954556672839135
# 3.3355449286683165
# 3.3360754557841

# %% [markdown]
# # Removal of outliers through z score

# %%
A_o = A[(z < 3).all(axis=1)]

# %%
A_o.head()
# Out:
#         msisdn state  accountLength  areaCode internationalPlan voiceMailPlan  \
# 0  22241029622    KS            128       415                no           yes
# 1  22241029627    OH            107       415                no           yes
# 2  22241029639    NJ            137       415                no            no
# 3  22241029641    OH             84       408               yes            no
# 4  22241029646    OK             75       415               yes            no
#
#    numberVmailMessages  totalDayMinutes  totalDayCalls  totalDayCharge  ...  \
# 0                   25            265.1            110           45.07  ...
# 1                   26            161.6            123           27.47  ...
# 2                    0            243.4            114           41.38  ...
# 3                    0            299.4             71           50.90  ...
# 4                    0            166.7            113           28.34  ...
#
# ...

# %%
A.shape
#A.head()
# Out:
# (2890, 21)

# %%
A_o.shape
# Out:
# (2758, 21)

# %%
# to chk whether outliers are removed or not :==

CAT_o=[]
CON_o=[]
for i in A_o.columns:
    if(A_o[i].dtypes=='object'):
        CAT_o.append(i)
    else:
        CON_o.append(i)
        

import matplotlib.pyplot as plt
for i in CON_o:
    plt.scatter(A_o[i],A_o.accountLength,c="red")
    plt.ylabel('accountLength')
    plt.xlabel(i)
    plt.title("accountLength vs %s"%i)
    plt.show()

# %%
for i in CAT_o:
    print(i)
    sb.boxplot(A_o[i],A_o.accountLength)
    plt.show()
# Out:
# state
# internationalPlan
# voiceMailPlan

# %%
min(A.accountLength)
# Out:
# 1

# %%
max(A.accountLength)
# Out:
# 243

# %%
min(A_o.accountLength)
# Out:
# 1

# %%
max(A_o.accountLength)
# Out:
# 217

# %% [markdown]
# # 2nd method to find outliers is IQR score -

# %%
#Q1 = A.quantile(0.25)
#Q3 = A.quantile(0.75)
#IQR = Q3 - Q1
#print(IQR)

# %%
#The data point where we have False that means these values are valid whereas True indicates presence of an outlier.

#outliers = (A < (Q1 - 1.5 * IQR)) |(A > (Q3 + 1.5 * IQR))
#print(A < (Q1 - 1.5 * IQR)) |(A > (Q3 + 1.5 * IQR))

# %%
#Just like Z-score we can use previously calculated IQR score to filter out the outliers by keeping only valid values.

#A_out = A[~((A < (Q1 - 1.5 * IQR)) |(A > (Q3 + 1.5 * IQR))).any(axis=1)]
#A_out.shape

# %%
#A_o.shape

# %%
#A.shape

# %%
#min(A_out.accountLength)

# %%
#max(A_out.accountLength)

# %%
# to chk whether outliers are removed or not :==

#CAT_out=[]
#CON_out=[]
#for i in A_out.columns:
 #   if(A_out[i].dtypes=='object'):
  #      CAT_out.append(i)
   #3 else:
     #   CON_out.append(i)
        

#import matplotlib.pyplot as plt
#for i in CON_out:
    #plt.scatter(A_out[i],A_out.accountLength,c="red")
    #plt.ylabel('accountLength')
    #plt.xlabel(i)
    #plt.title("accountLength vs %s"%i)
    #plt.show()

# %%
#for i in CAT_out:
 #   print(i)
  #  sb.boxplot(A_out[i],A_out.accountLength)
   # plt.show()

# %% [markdown]
# # One hot Encoding

# %%
A_o['internationalPlan_Dummy'] = pd.get_dummies(A_o["internationalPlan"],drop_first= True)
A_o['voiceMailPlan_Dummy'] = pd.get_dummies(A_o['voiceMailPlan'],drop_first= True)
A_o['churner_Dummy'] = pd.get_dummies(A_o['churner'],drop_first= True)
# Out:
# C:\Users\my lappy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\my lappy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\my lappy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
A_o.head()
# Out:
#         msisdn state  accountLength  areaCode internationalPlan voiceMailPlan  \
# 0  22241029622    KS            128       415                no           yes
# 1  22241029627    OH            107       415                no           yes
# 2  22241029639    NJ            137       415                no            no
# 3  22241029641    OH             84       408               yes            no
# 4  22241029646    OK             75       415               yes            no
#
#    numberVmailMessages  totalDayMinutes  totalDayCalls  totalDayCharge  ...  \
# 0                   25            265.1            110           45.07  ...
# 1                   26            161.6            123           27.47  ...
# 2                    0            243.4            114           41.38  ...
# 3                    0            299.4             71           50.90  ...
# 4                    0            166.7            113           28.34  ...
#
# ...

# %%
A_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2758 entries, 0 to 2889
# Data columns (total 24 columns):
# msisdn                        2758 non-null int64
# state                         2758 non-null object
# accountLength                 2758 non-null int64
# areaCode                      2758 non-null int64
# internationalPlan             2758 non-null object
# voiceMailPlan                 2758 non-null object
# numberVmailMessages           2758 non-null int64
# totalDayMinutes               2758 non-null float64
# totalDayCalls                 2758 non-null int64
# totalDayCharge                2758 non-null float64
# totalEveMinutes               2758 non-null float64
# totalEveCalls                 2758 non-null int64
# totalEveCharge                2758 non-null float64
# totalNightMinutes             2758 non-null float64
# totalNightCalls               2758 non-null int64
# totalNightCharge              2758 non-null float64
# ...

# %% [markdown]
# # Logistic Regression

# %%
#X=A_o[['msisdn','accountLength','areaCode','internationalPlan','voiceMailPlan','numberVmailMessages','totalDayMinutes',
#'totalDayCharge','totalDayCalls','totalDayCharge','totalEveCalls','totalEveCharge','totalNightMinutes',
 # 'totalNightCalls','totalNightCharge', 'totalIntlMinutes','totalIntlCalls','totalIntlCharge',
  # 'numberCustomerServiceCalls','internationalPlan_Dummy','voiceMailPlan_Dummy']]

#X=A_o[['numberVmailMessages','totalDayMinutes',
 #       'totalDayCalls','totalNightMinutes',
  #       'totalIntlMinutes','totalIntlCalls',
   #   'numberCustomerServiceCalls','internationalPlan_Dummy']]

    
#on taking novmailmsgs not a drastic difference is there    
X=A_o[['totalDayMinutes','totalEveMinutes','totalNightMinutes',
       'totalIntlMinutes','totalIntlCalls',
       'numberCustomerServiceCalls','voiceMailPlan_Dummy']]


Y=A_o[["churner_Dummy"]]
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
model1=lr.fit(xtrain,ytrain)
pred=model1.predict(xtest)
# Out:
# C:\Users\my lappy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\my lappy\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#pred

# %%
ytest['predictedchurner']=pred
# Out:
# C:\Users\my lappy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#pd.set_option('display.max_rows',1500)
ytest.head()
# Out:
#       churner_Dummy  predictedchurner
# 2803              0                 0
# 2404              0                 0
# 1810              0                 0
# 523               0                 0
# 2612              0                 0

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print(accuracy_score(ytest['churner_Dummy'],pred))
print(confusion_matrix(ytest['churner_Dummy'],pred))
# Out:
# 0.875
# [[478   1]
#  [ 68   5]]

# %%
pred1=model1.predict_proba(xtest)
from sklearn.metrics import accuracy_score, confusion_matrix,roc_curve,auc
fpr,tpr,threshold=roc_curve(ytest['churner_Dummy'],pred1[:,1])
roc_auc=auc(fpr,tpr)

# %%
#pred1

# %%
import matplotlib.pyplot as plt   #fpr= false positive rate , tpr-true positive rate
plt.plot(fpr,tpr,roc_auc)
plt.show()

# %% [markdown]
# # Random Forest

# %%
X=A_o[['totalDayMinutes','totalEveMinutes','totalNightMinutes',
       'totalIntlMinutes',
       'numberCustomerServiceCalls','totalIntlCalls','voiceMailPlan_Dummy']]

Y=A_o[["churner_Dummy"]]


from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=20)


from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=100)
model_rfc=rfc.fit(xtrain,ytrain)
pred_rfc=model_rfc.predict(xtest)
from sklearn.metrics import confusion_matrix,accuracy_score
print(confusion_matrix(ytest['churner_Dummy'],pred_rfc))
print(accuracy_score(ytest['churner_Dummy'],pred_rfc))
# Out:
# C:\Users\my lappy\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# [[477   2]
#  [ 41  32]]
# 0.9221014492753623

# %%
X.columns
# Out:
# Index(['totalDayMinutes', 'totalEveMinutes', 'totalNightMinutes',
#        'totalIntlMinutes', 'numberCustomerServiceCalls', 'totalIntlCalls',
#        'voiceMailPlan_Dummy'],
#       dtype='object')

# %%
model_rfc.feature_importances_
# Out:
# array([0.32423901, 0.19205109, 0.13151119, 0.13148904, 0.11914435,
#        0.0617906 , 0.03977472])

# %%
import matplotlib.pyplot as plt 
plt.barh(X.columns,model_rfc.feature_importances_)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# # Naive Bayes

# %%
#X=A_o[['totalDayMinutes','totalDayCalls','totalEveMinutes','totalNightMinutes',
 #      'totalIntlMinutes',
  #     'numberCustomerServiceCalls']]#,'numberVmailMessages','totalIntlCalls','voiceMailPlan_Dummy']]

X=A_o[['totalDayMinutes','totalEveMinutes','totalNightMinutes',
       'totalIntlMinutes',
       'numberCustomerServiceCalls','totalIntlCalls','voiceMailPlan_Dummy']]

Y=A_o[["churner_Dummy"]]

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=20)


from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
model4=nb.fit(xtrain,ytrain)
pred4=model4.predict(xtest)
from sklearn.metrics import confusion_matrix,accuracy_score
print(confusion_matrix(ytest['churner_Dummy'],pred4))
print(accuracy_score(ytest['churner_Dummy'],pred4))
# Out:
# [[473   6]
#  [ 56  17]]
# 0.8876811594202898
# C:\Users\my lappy\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Adaboost

# %%
#X=A_o[['totalDayMinutes','totalDayCalls','totalEveMinutes','totalNightMinutes',
 #      'totalIntlMinutes',
  #     'numberCustomerServiceCalls']]#,'numberVmailMessages','totalIntlCalls','voiceMailPlan_Dummy']]

X=A_o[['totalDayMinutes','totalDayCalls','totalEveMinutes','totalNightMinutes',
       'totalIntlMinutes',
       'numberCustomerServiceCalls','totalIntlCalls','voiceMailPlan_Dummy']]

Y=A_o[["churner_Dummy"]]

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=20)


from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
abc=AdaBoostClassifier(DecisionTreeClassifier(max_depth=2),n_estimators=10)
model5=abc.fit(xtrain,ytrain)
pred5=model5.predict(xtest)

from sklearn.metrics import accuracy_score
print(accuracy_score(ytest['churner_Dummy'],pred5))
print(confusion_matrix(ytest['churner_Dummy'],pred5))
# Out:
# 0.9057971014492754
# [[466  13]
#  [ 39  34]]
# C:\Users\my lappy\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Decision Tree

# %%
X=A_o[['totalDayMinutes','totalDayCalls','totalEveMinutes','totalNightMinutes',
       'totalIntlMinutes',
       'numberCustomerServiceCalls','totalIntlCalls','voiceMailPlan_Dummy']]

Y=A_o[["churner_Dummy"]]

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=20)

from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(criterion="entropy",min_samples_leaf=7)
model_dtc=dtc.fit(xtrain,ytrain)
pred_dtc=model_dtc.predict(xtest)
from sklearn.metrics import accuracy_score
print(accuracy_score(ytest['churner_Dummy'],pred_dtc))
print(confusion_matrix(ytest['churner_Dummy'],pred_dtc))
# Out:
# 0.8804347826086957
# [[449  30]
#  [ 36  37]]

# %%
X=A_o[['totalDayMinutes','totalDayCalls','totalEveMinutes','totalNightMinutes',
       'totalIntlMinutes',
       'numberCustomerServiceCalls','totalIntlCalls','voiceMailPlan_Dummy']]

Y=A_o[["churner_Dummy"]]

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=20)

from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(criterion="gini",min_samples_leaf=7)
model_dtc=dtc.fit(xtrain,ytrain)
pred_dtc=model_dtc.predict(xtest)
from sklearn.metrics import accuracy_score
print(accuracy_score(ytest['churner_Dummy'],pred_dtc))
print(confusion_matrix(ytest['churner_Dummy'],pred_dtc))
# Out:
# 0.8840579710144928
# [[454  25]
#  [ 39  34]]

# %%
#from sklearn.tree import export_graphviz
#export_graphviz(dtc,out_file)

# %%
#import pydotplus as pdp
#graph=pdp.graph_from_dot_file("/Users/my lappy/Desktop/dummy_work/e2")
#from IPython.display import Image
#Image(graph.create_jpg())
